# %%
import requests
import pprint
import sys
import os
import datetime
import time
import pandas as pd
import mysql.connector
from mysql.connector import errorcode
import argparse
import glob

# %%
now = time.time()

now, int(now), float(now)

# %%
resp = requests.get('https://jsonplaceholder.typicode.com/todos')
rset = resp.json()
for idx,data in enumerate(rset):
    print(idx + 1,data['title'])

# %%
resp = requests.get('https://api.liquid.com/products')
rset = resp.json()
pairs = []
for idx,data in enumerate(rset):
    pairs.append(data['currency_pair_code'])
pairs.sort()
pairs
# Out:
# ['1WOBTC',
#  '1WOETH',
#  '1WOQASH',
#  'ADHBTC',
#  'ADHETH',
#  'ADHQASH',
#  'ALXBTC',
#  'ALXETH',
#  'ALXQASH',
#  'AMLTBTC',
#  'AMLTETH',
#  'AMLTQASH',
#  'BCHBTC',
#  'BCHJPY',
#  'BCHSGD',
#  'BCHUSD',
#  'BMCBTC',
#  'BMCETH',
#  'BMCQASH',
#  'BRCBCH',
#  'BRCBTC',
#  'BRCETH',
#  'BRCQASH',
#  'BTCAUD',
#  'BTCCNY',
#  'BTCEUR',
#  'BTCHKD',
#  'BTCIDR',
#  'BTCINR',
#  'BTCJPY',
#  'BTCPHP',
#  'BTCSGD',
#  'BTCUSD',
#  'BTRNBTC',
#  'BTRNETH',
#  'BTRNQASH',
#  'CANBTC',
#  'CANETH',
#  'CANQASH',
#  'CHIBTC',
#  'CHIETH',
#  'CHIQASH',
#  'CMCTBTC',
#  'CMCTETH',
#  'CMCTQASH',
#  'CRPTBTC',
#  'CRPTETH',
#  'CRPTQASH',
#  'DACSBTC',
#  'DACSETH',
#  'DACSQASH',
#  'DASHBTC',
#  'DASHEUR',
#  'DASHJPY',
#  'DASHSGD',
#  'DASHUSD',
#  'DENTBTC',
#  'DENTETH',
#  'DENTQASH',
#  'DRGBTC',
#  'DRGETH',
#  'DRGQASH',
#  'EARTHBTC',
#  'EARTHETH',
#  'EARTHQASH',
#  'ECHBTC',
#  'ECHETH',
#  'ECHQASH',
#  'ELYBTC',
#  'ELYETH',
#  'ELYQASH',
#  'ENJBTC',
#  'ENJETH',
#  'ENJQASH',
#  'ETCBTC',
#  'ETHAUD',
#  'ETHBTC',
#  'ETHCNY',
#  'ETHEUR',
#  'ETHHKD',
#  'ETHIDR',
#  'ETHINR',
#  'ETHJPY',
#  'ETHPHP',
#  'ETHSGD',
#  'ETHUSD',
#  'ETNBTC',
#  'ETNETH',
#  'ETNQASH',
#  'EZTBTC',
#  'EZTETH',
#  'EZTQASH',
#  'FCTBTC',
#  'FCTETH',
#  'FDXBTC',
#  'FDXETH',
#  'FDXQASH',
#  'FLIXXBTC',
#  'FLIXXETH',
#  'FLIXXQASH',
#  'FLPBTC',
#  'FLPETH',
#  'FLPQASH',
#  'FLUZBTC',
#  'FLUZETH',
#  'FLUZQASH',
#  'FSNBTC',
#  'FSNETH',
#  'FSNQASH',
#  'FTTBTC',
#  'FTTETH',
#  'FTTQASH',
#  'FTXBTC',
#  'FTXETH',
#  'FTXQASH',
#  'GATBTC',
#  'GATETH',
#  'GATQASH',
#  'GENBTC',
#  'GENETH',
#  'GENQASH',
#  'GETBTC',
#  'GETETH',
#  'GETQASH',
#  'GZEBTC',
#  'GZEETH',
#  'GZEQASH',
#  'HAVBTC',
#  'HAVETH',
#  'HAVQASH',
#  'HEROBTC',
#  'HEROETH',
#  'HEROQASH',
#  'IDHBTC',
#  'IDHETH',
#  'IDHQASH',
#  'IGNXBTC',
#  'IGNXETH',
#  'IGNXQASH',
#  'IHFBTC',
#  'IHFETH',
#  'INDBTC',
#  'INDETH',
#  'IPSXBTC',
#  'IPSXETH',
#  'IPSXQASH',
#  'IXTBTC',
#  'IXTETH',
#  'IXTQASH',
#  'KRLBTC',
#  'KRLETH',
#  'KRLQASH',
#  'LALABTC',
#  'LALAETH',
#  'LALAQASH',
#  'LDCBTC',
#  'LDCETH',
#  'LDCQASH',
#  'LIKEBTC',
#  'LIKEETH',
#  'LIKEQASH',
#  'LNDBTC',
#  'LNDETH',
#  'LNDQASH',
#  'LTCBTC',
#  'MCOBTC',
#  'MCOETH',
#  'MCOQASH',
#  'MGOBTC',
#  'MGOETH',
#  'MGOQASH',
#  'MITHBTC',
#  'MITHETH',
#  'MITHQASH',
#  'MITXBTC',
#  'MITXETH',
#  'MITXQASH',
#  'MRKBTC',
#  'MRKETH',
#  'MRKQASH',
#  'MTBTC',
#  'MTETH',
#  'MTNBTC',
#  'MTNETH',
#  'MTNQASH',
#  'MTQASH',
#  'NEOBTC',
#  'NEOETH',
#  'NEOEUR',
#  'NEOJPY',
#  'NEOSGD',
#  'NEOUSD',
#  'NPLCBTC',
#  'NPLCETH',
#  'NPLCQASH',
#  'OAXBTC',
#  'OAXETH',
#  'ONGBTC',
#  'ONGETH',
#  'ONGQASH',
#  'ONTBTC',
#  'ONTETH',
#  'ONTJPY',
#  'ONTQASH',
#  'ONTUSD',
#  'PALBTC',
#  'PALETH',
#  'PALQASH',
#  'PLCBTC',
#  'PLCETH',
#  'PLCQASH',
#  'PWVBTC',
#  'PWVETH',
#  'PWVQASH',
#  'QASHAUD',
#  'QASHBTC',
#  'QASHCNY',
#  'QASHETH',
#  'QASHEUR',
#  'QASHHKD',
#  'QASHIDR',
#  'QASHINR',
#  'QASHJPY',
#  'QASHPHP',
#  'QASHSGD',
#  'QASHUSD',
#  'QTUMBTC',
#  'QTUMETH',
#  'QTUMEUR',
#  'QTUMJPY',
#  'QTUMSGD',
#  'QTUMUSD',
#  'RBLXBTC',
#  'RBLXETH',
#  'RBLXQASH',
#  'REPBTC',
#  'RKTAUD',
#  'RKTBTC',
#  'RKTETH',
#  'RKTEUR',
#  'RKTJPY',
#  'RKTQASH',
#  'RKTSGD',
#  'RKTUSD',
#  'SALBTC',
#  'SALETH',
#  'SALQASH',
#  'SERBTC',
#  'SERETH',
#  'SERQASH',
#  'SGNBTC',
#  'SGNETH',
#  'SGNQASH',
#  'SHPBTC',
#  'SHPETH',
#  'SHPQASH',
#  'SIXBTC',
#  'SNIPBTC',
#  'SNIPETH',
#  'SNIPQASH',
#  'SPHTXBTC',
#  'SPHTXETH',
#  'SPHTXQASH',
#  'STACBTC',
#  'STACETH',
#  'STACQASH',
#  'STORJBTC',
#  'STORJETH',
#  'STUBTC',
#  'STUETH',
#  'STUQASH',
#  'STXBTC',
#  'STXETH',
#  'THRTBTC',
#  'THRTETH',
#  'THRTQASH',
#  'TPAYBTC',
#  'TPAYETH',
#  'TPAYQASH',
#  'TPTBTC',
#  'TPTETH',
#  'TPTQASH',
#  'TRXBTC',
#  'TRXETH',
#  'UBTBTC',
#  'UBTCBTC',
#  'UBTCETH',
#  'UBTCJPY',
#  'UBTCQASH',
#  'UBTCSGD',
#  'UBTCUSD',
#  'UBTETH',
#  'UBTQASH',
#  'UKGBTC',
#  'UKGETH',
#  'UKGQASH',
#  'VETBTC',
#  'VETETH',
#  'VIOBTC',
#  'VIOETH',
#  'VIOQASH',
#  'VUUBTC',
#  'VUUETH',
#  'VUUQASH',
#  'VZTBTC',
#  'VZTETH',
#  'VZTQASH',
#  'WINBTC',
#  'WINETH',
#  'WINQASH',
#  'XEMBTC',
#  'XESBTC',
#  'XESETH',
#  'XESQASH',
#  'XLMBTC',
#  'XLMETH',
#  'XMRBTC',
#  'XNKBTC',
#  'XNKETH',
#  'XNKQASH',
#  'XRPBTC',
#  'XRPEUR',
#  'XRPIDR',
#  'XRPJPY',
#  'XRPQASH',
#  'XRPSGD',
#  'XRPUSD',
#  'ZCOBTC',
#  'ZCOETH',
#  'ZCOQASH',
#  'ZECBTC',
#  'ZPRBTC',
#  'ZPRETH',
#  'ZPRQASH']
